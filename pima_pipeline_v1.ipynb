# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudra-CSER/-Healthcare-Risk-Predictor/blob/main/pima_pipeline_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Raw CSV/diabetes.csv')

# %%
print(df.shape)
# Out:
# (768, 9)

# %%
print(df.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df[df['Outcome'] == 0 ]['Glucose'].mean()
# Out:
# np.float64(109.98)

# %%
df[df['Outcome'] == 1]['Glucose'].mean()
# Out:
# np.float64(141.25746268656715)

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
Short_bmi = df.sort_values(by='BMI', ascending=True)
print(Short_bmi.head())
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 49             7      105              0              0        0  0.0
# 60             2       84              0              0        0  0.0
# 706           10      115              0              0        0  0.0
# 81             2       74              0              0        0  0.0
# 684            5      136             82              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 49                      0.305   24        0
# 60                      0.304   21        0
# 706                     0.261   30        1
# 81                      0.102   22        0
# 684                     0.640   69        0

# %%
sv = df[df['Outcome']== 1]
sv.to_csv('/content/drive/MyDrive/Raw CSV/diabetes.csv', index = False)

# %%
sv = df[df['Outcome']== 0]
sv.to_csv('/content/drive/MyDrive/Raw CSV/diabetes(0).csv', index = False)

# %% [markdown]
# ### Project Steps
#
# 1.  **Import Libraries**: Started by importing `numpy` and `pandas` for data manipulation.
# 2.  **Mount Google Drive**: Mounted Google Drive to access files, specifically using `drive.mount('/content/drive')`.
# 3.  **Load Data**: Read the `diabetes.csv` file from `/content/drive/MyDrive/Raw CSV/diabetes.csv` into a pandas DataFrame.
#     *   *(Note: Initially, I faced challenges with file paths and refined the loading process to directly fetch from Drive. I ensured raw data and output folders were clearly separated for better organization.)*
# 4.  **Initial Data Inspection**: Printed the DataFrame's `shape`, `dtypes`, and `isnull().sum()` to understand its structure and check for missing values.
# 5.  **Analyze Glucose Levels by Outcome**: Calculated the mean glucose levels for patients with diabetes (Outcome = 1) and without diabetes (Outcome = 0).
# 6.  **Count Outcome Values**: Counted the occurrences of each `Outcome` value to see the distribution of diabetic vs. non-diabetic patients.
# 7.  **Sort by BMI**: Sorted the DataFrame by 'BMI' in ascending order and displayed the top 5 rows to examine patients with the lowest BMI values.
# 8.  **Export Filtered Data**: Created separate CSV files for diabetic patients (`Outcome = 1`) and non-diabetic patients (`Outcome = 0`) and saved them to Google Drive. This involved creating distinct folders for organized output.
